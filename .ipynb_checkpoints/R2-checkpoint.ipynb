# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import statsmodels.tsa.stattools as st
warnings.filterwarnings("ignore")

# %%
def Remove_Outlier_Indices(df):
    Q1 = df.quantile(0.1)
    Q3 = df.quantile(0.9)
    IQR = Q3 - Q1
    trueList = ~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR)))
    return trueList

# %%
FOLDER_PATH = 'data/'
DATA_COLUMNS = ['wiki_movie_id', 'freebase_movie_id', 'movie_name',
       'movie_box_office_revenue', 'movie_runtime', 'languages', 'countries',
       'genres', 'imdb_id', 'cast', 'rating', 'votes', 'budget', 'plot',
       'characters_names', 'main_character', 'release_year']
df = pd.read_csv(FOLDER_PATH + 'movie_processed.csv', names=DATA_COLUMNS, header=0, index_col=0, parse_dates=['release_year'])
df.head()
# Out:
#    wiki_movie_id freebase_movie_id                 movie_name  \
# 0         975900         /m/03vyhn             Ghosts of Mars
# 1        9363483        /m/0285_cd           White Of The Eye
# 2         261236         /m/01mrr1          A Woman in Flames
# 3       18998739        /m/04jcqvw  The Sorcerer's Apprentice
# 4        6631279         /m/0gffwj                Little city
#
#    movie_box_office_revenue  movie_runtime    languages  \
# 0                14010832.0           98.0  ['English']
# 1                       NaN          110.0  ['English']
# 2                       NaN          106.0   ['German']
# 3                       NaN           86.0  ['English']
# 4                       NaN           93.0  ['English']
#
#                       countries  \
# 0  ['United States of America']
# 1            ['United Kingdom']
# 2                   ['Germany']
# 3              ['South Africa']
# 4  ['United States of America']
#
#                                               genres   imdb_id  \
# 0  ['Thriller', 'Science Fiction', 'Horror', 'Adv...  228333.0
# 1  ['Thriller', 'Erotic thriller', 'Psychological...       NaN
# 2                                          ['Drama']   83949.0
# 3  ['Family Film', 'Fantasy', 'Adventure', 'World...       NaN
# 4  ['Romantic comedy', 'Ensemble Film', 'Comedy-d...       NaN
#
#                                                 cast  rating    votes  \
# 0  ['Natasha Henstridge', 'Ice Cube', 'Jason Stat...     4.9  55370.0
# 1                                                NaN     NaN      NaN
# 2  ['Gudrun Landgrebe', 'Mathieu Carrière', 'Hann...     6.0    591.0
# 3                                                NaN     NaN      NaN
# 4                                                NaN     NaN      NaN
#
#        budget                                               plot  \
# 0  28000000.0  Set in the second half of the 22nd century, th...
# 1         NaN  A series of murders of rich young women throug...
# 2         NaN  Eva, an upper class housewife, becomes frustra...
# 3         NaN  Every hundred years, the evil Morgana  returns...
# 4         NaN  Adam, a San Francisco-based artist who works a...
#
#                                     characters_names  \
# 0  ['Akooshay', 'Lieutenant Melanie Ballard', 'De...
# 1                                                 []
# 2                                                 []
# 3                                        ['Morgana']
# 4                                ['Rebecca', 'Nina']
#
#                main_character release_year
# 0  Lieutenant Melanie Ballard       2001.0
# 1                         NaN       1987.0
# 2                         NaN       1983.0
# 3                     Morgana       2002.0
# 4                        Nina       1997.0

# %%
def yearly_avg(df, cols):
    df = df[Remove_Outlier_Indices(df)]
    df_avg = [y for y in df['release_year'].unique() if not pd.isnull(y)]
    df_avg.sort()
    df_avg = pd.DataFrame(np.array([df_avg] * (2*len(cols))).T, index = df_avg, columns=[col+'_avg' for col in cols]+[col+'_std' for col in cols])
    for i, row in df_avg.iterrows():
        for col in cols:
            row[col+'_avg'] = df[df['release_year'] == i][col].mean()
            row[col+'_std'] = df[df['release_year'] == i][col].std()
    return df_avg


yearly_avg(df, ['movie_runtime']).plot()
yearly_avg(df, ['movie_box_office_revenue','budget']).plot()
# Out:
# <AxesSubplot:>

# %%
def test_ganger(cols, maxlag):
    st.grangercausalitytests(yearly_avg(df, cols)[list(map(lambda x: x+'_avg', cols))].dropna(), maxlag=maxlag)
    
test_ganger(['movie_box_office_revenue', 'movie_runtime'], 10)
test_ganger(['movie_box_office_revenue', 'budget'], 10)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0027  , p=0.0865  , df_denom=90, df_num=1
# ssr based chi2 test:   chi2=3.1028  , p=0.0782  , df=1
# likelihood ratio test: chi2=3.0522  , p=0.0806  , df=1
# parameter F test:         F=3.0027  , p=0.0865  , df_denom=90, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3534  , p=0.7033  , df_denom=87, df_num=2
# ssr based chi2 test:   chi2=0.7474  , p=0.6882  , df=2
# likelihood ratio test: chi2=0.7444  , p=0.6892  , df=2
# parameter F test:         F=0.3534  , p=0.7033  , df_denom=87, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.4129  , p=0.0062  , df_denom=84, df_num=3
# ssr based chi2 test:   chi2=14.3420 , p=0.0025  , df=3
# likelihood ratio test: chi2=13.3181 , p=0.0040  , df=3
# parameter F test:         F=4.4129  , p=0.0062  , df_denom=84, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1753  , p=0.0791  , df_denom=81, df_num=4
# ssr based chi2 test:   chi2=9.6678  , p=0.0464  , df=4
# likelihood ratio test: chi2=9.1830  , p=0.0567  , df=4
# parameter F test:         F=2.1753  , p=0.0791  , df_denom=81, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9834  , p=0.4334  , df_denom=78, df_num=5
# ssr based chi2 test:   chi2=5.6103  , p=0.3460  , df=5
# likelihood ratio test: chi2=5.4405  , p=0.3645  , df=5
# parameter F test:         F=0.9834  , p=0.4334  , df_denom=78, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7280  , p=0.6284  , df_denom=75, df_num=6
# ssr based chi2 test:   chi2=5.1254  , p=0.5278  , df=6
# likelihood ratio test: chi2=4.9817  , p=0.5462  , df=6
# parameter F test:         F=0.7280  , p=0.6284  , df_denom=75, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3623  , p=0.9211  , df_denom=72, df_num=7
# ssr based chi2 test:   chi2=3.0642  , p=0.8790  , df=7
# likelihood ratio test: chi2=3.0115  , p=0.8839  , df=7
# parameter F test:         F=0.3623  , p=0.9211  , df_denom=72, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3482  , p=0.9435  , df_denom=69, df_num=8
# ssr based chi2 test:   chi2=3.4723  , p=0.9013  , df=8
# likelihood ratio test: chi2=3.4040  , p=0.9065  , df=8
# parameter F test:         F=0.3482  , p=0.9435  , df_denom=69, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4155  , p=0.9224  , df_denom=66, df_num=9
# ssr based chi2 test:   chi2=4.8158  , p=0.8501  , df=9
# likelihood ratio test: chi2=4.6844  , p=0.8609  , df=9
# parameter F test:         F=0.4155  , p=0.9224  , df_denom=66, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4627  , p=0.9077  , df_denom=63, df_num=10
# ssr based chi2 test:   chi2=6.1688  , p=0.8009  , df=10
# likelihood ratio test: chi2=5.9528  , p=0.8192  , df=10
# parameter F test:         F=0.4627  , p=0.9077  , df_denom=63, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=13.4219 , p=0.0004  , df_denom=89, df_num=1
# ssr based chi2 test:   chi2=13.8743 , p=0.0002  , df=1
# likelihood ratio test: chi2=12.9227 , p=0.0003  , df=1
# parameter F test:         F=13.4219 , p=0.0004  , df_denom=89, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.1414  , p=0.0482  , df_denom=86, df_num=2
# ssr based chi2 test:   chi2=6.6480  , p=0.0360  , df=2
# likelihood ratio test: chi2=6.4164  , p=0.0404  , df=2
# parameter F test:         F=3.1414  , p=0.0482  , df_denom=86, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0683  , p=0.3671  , df_denom=83, df_num=3
# ssr based chi2 test:   chi2=3.4751  , p=0.3240  , df=3
# likelihood ratio test: chi2=3.4097  , p=0.3327  , df=3
# parameter F test:         F=1.0683  , p=0.3671  , df_denom=83, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6277  , p=0.6441  , df_denom=80, df_num=4
# ssr based chi2 test:   chi2=2.7934  , p=0.5930  , df=4
# likelihood ratio test: chi2=2.7505  , p=0.6004  , df=4
# parameter F test:         F=0.6277  , p=0.6441  , df_denom=80, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4614  , p=0.8038  , df_denom=77, df_num=5
# ssr based chi2 test:   chi2=2.6363  , p=0.7558  , df=5
# likelihood ratio test: chi2=2.5976  , p=0.7617  , df=5
# parameter F test:         F=0.4614  , p=0.8038  , df_denom=77, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4851  , p=0.8174  , df_denom=74, df_num=6
# ssr based chi2 test:   chi2=3.4223  , p=0.7543  , df=6
# likelihood ratio test: chi2=3.3567  , p=0.7629  , df=6
# parameter F test:         F=0.4851  , p=0.8174  , df_denom=74, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4084  , p=0.8941  , df_denom=71, df_num=7
# ssr based chi2 test:   chi2=3.4631  , p=0.8391  , df=7
# likelihood ratio test: chi2=3.3952  , p=0.8462  , df=7
# parameter F test:         F=0.4084  , p=0.8941  , df_denom=71, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6174  , p=0.7603  , df_denom=68, df_num=8
# ssr based chi2 test:   chi2=6.1738  , p=0.6278  , df=8
# likelihood ratio test: chi2=5.9599  , p=0.6517  , df=8
# parameter F test:         F=0.6174  , p=0.7603  , df_denom=68, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4978  , p=0.8707  , df_denom=65, df_num=9
# ssr based chi2 test:   chi2=5.7902  , p=0.7607  , df=9
# likelihood ratio test: chi2=5.5994  , p=0.7792  , df=9
# parameter F test:         F=0.4978  , p=0.8707  , df_denom=65, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4229  , p=0.9302  , df_denom=62, df_num=10
# ssr based chi2 test:   chi2=5.6611  , p=0.8429  , df=10
# likelihood ratio test: chi2=5.4764  , p=0.8572  , df=10
# parameter F test:         F=0.4229  , p=0.9302  , df_denom=62, df_num=10
